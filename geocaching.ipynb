# %%
import re
import csv
import requests
from bs4 import BeautifulSoup


url = "https://www.geocaching.com/account/signin"

class geocache():
    def __init__(self, name):
        self.name = name
        self.nCor = ""
        self.eCor = ""
        self.hint = ""
        self.geoName = ""
        self.list = []
    def fetch(self, session, geoId):
        listAnswer = []
        response = session.get("https://www.geocaching.com/geocache/" + geoId)
        docCache = BeautifulSoup(response.text, "html.parser")
        latLon = docCache.select_one("#uxLatLon").text
        geoName = docCache.select_one("#ctl00_ContentBody_CacheName").text
        hint = docCache.select_one("#div_hint").text
        splitText = re.findall(r"\d+", latLon)
        try:
            nCor = int("".join(splitText[0:3]))
            eCor = int("".join(splitText[3:6]))
        except Exception as e:
            print ("No number")
        findSpan = docCache.body.find("span", id="ctl00_ContentBody_LongDescription")
        for spanText in findSpan.find_all("span", style="font-family:Times New Roman,Times,serif;", text = re.compile('^a|^b|^c')):
            listAnswer.append(spanText.text)
        gcList = [nCor, eCor, geoName, hint, listAnswer]
        return gcList
    
    def geocacheList(self, session):
        geocacheList = []
        response = session.get("https://www.geocaching.com/play/search?types=8&a=0&sc=False&owner[0]=WarriorFoxes&sort=PlaceDate&asc=False")
        docCache = BeautifulSoup(response.text, "html.parser")
        for item in docCache.find_all(attrs={"data-id": True}):
            geocacheList.append(item['data-id'])
        return geocacheList    
        
class geocacheFetch():
    def __init__(self):
        self.session = ""
    def login(self):
        with requests.Session() as s:
            #insert Password and username here
            payload = {'UsernameOrEmail':'your_username', 'Password':'your_password', "__RequestVerificationToken": ""}        
            request = s.get(url)
            docLogin = BeautifulSoup(request.text, "html.parser")
            try:
                tokenValue = docLogin.find('input', {"name": "__RequestVerificationToken"}).get('value')
                payload['__RequestVerificationToken'] = tokenValue
                r = s.post(url, data=payload)    
            except Exceptions as e:
                print ("no login")
            return s

listCaches = []
   
fetcher = geocacheFetch()
fetcher.session = fetcher.login()

obj = geocache("")

listGeocaches = obj.geocacheList(fetcher.session)

for gc in listGeocaches:  
    listCache = []
    obj.name = gc
    corList = obj.fetch(fetcher.session, obj.name)
    obj.nCor = corList[0]
    obj.eCor = corList[1]
    obj.hint = corList[3]
    obj.geoName = corList[2]
    obj.list = corList[4]
    gcNumber = re.findall(r"\d+", obj.geoName)
    try:
        gcInt = int("".join(gcNumber[0:1]))
    except Exception as e:
        print ("No number")
    listCache.append(gcInt)
    listCache.append(obj.geoName)
    listCache.append(gc)
    listCache.append(obj.nCor)
    listCache.append(obj.eCor)
    for elements in obj.list:
        listCache.append(elements)
    listCaches.append(listCache) 
    

print(listCaches)

with open('gc.csv', 'w', encoding='UTF8') as csvfile:
    geowriter = csv.writer(csvfile, delimiter=",")
    for cache in listCaches:
        geowriter.writerow(cache)
# Out:
# No number
# [[14, 'Schach-Mattinger Runde #14', 'GC9B5JJ', 4857700, 1201100, 'a) 2 N+735/E+1.104', 'b) 6 N+802/E+1.059', 'c) 4 N+709/E+1.106'], [9, 'Schach-Mattinger Runde #9', 'GC9B5HR', 4857100, 1201200, 'a) 16 N+107/E+389', 'b) 24 N+107/E+355', 'c) 32 N+107/E+410'], [12, 'Schach-Mattinger Runde #12', 'GC9B5J7', 4857400, 1201100, 'a) 28 N+113/E+613', 'b) 32 N+127/E+713', 'c) 36 N+133/E+813'], [31, 'Schach-Mattinger Runde #31', 'GC9B5PZ', 4857300, 1200550, 'a) Anzeige und Begrenzung der zur Verfügung stehenden Bedenkzeit N-32/E-41.268', 'b) Anzeige des Spielendes nach Zeitablauf N+27/E-41.210', 'c) Unterbrechung eines Spiels wegen Pausen N-68/E-41.290'], [24, 'Schach-Mattinger Runde #24', 'GC9B5MZ', 4858000, 1200450, 'a) Ein Springer, der die Dame schlägt N-98/E+17', 'b) Ein Springer, der nur ein Feld ziehen darf N+51/E-65', 'c) Der Springer, der zu Beginn des Spiels nahe dem König steht N-47/E-98'], [23, 'Schach-Mattinger Runde #23', 'GC9B5MP', 4857900, 1200600, 'a) 4 N+120/E+10', 'b) 6 N+101/E-69', 'c) 8 N+20/E-8'], [27, 'Schach-Mattinger Runde #27', 'GC9B5NV', 4857700, 1200550, 'a) 6 N-10/E-40.377', 'b) 8 N+67/E-40.482', 'c) 10 N+97/E-40.692'], [28, 'Schach-Mattinger Runde #28', 'GC9B5P4', 4857600, 1200550, 'a) Die gegnerische Dame so anzugreifen, dass sie nicht mehr verteidigt und beim nächsten Zug geschlagen werden kann N+185/E-40.783', 'b) Möglichst viele gegnerische Figuren zu schlagen N+214/E-41.101', 'c) Den gegnerischen König so anzugreifen, dass er nicht mehr verteidigt und beim nächsten Zug geschlagen werden kann N+133/E-40.864'], [19, 'Schach-Mattinger Runde #19', 'GC9B5KA', 4857900, 1200900, 'a) Magnus Carlsen N+232/E+447', 'b) Ole Thorensen N+322/E+747', 'c) Nils Odegaard N+223/E+774'], [33, 'Schach-Mattinger Runde #33', 'GC9B5QF', 4857100, 1200450, 'a) Wenn eine Figur gleichzeitig mindestens drei gegnerische Figuren angreift N+28/E-40.952', 'b) Wenn eine Figur gleichzeitig zwei oder mehrere gegnerische Figuren angreift N-9/E-41.016', 'c) Unterbrechung des Spiels für eine Essenspause N+18/E-41.227'], [26, 'Schach-Mattinger Runde #26', 'GC9B5NG', 4857800, 1200450, 'a) e1 N-21/E-358', 'b) d1 N+38/E-446', 'c) d8 N+125/E-561'], [13, 'Schach-Mattinger Runde #13', 'GC9B5JB', 4857500, 1201100, 'a) 1 N+236/E+876', 'b) 2 N+329/E+787', 'c) 3 N+923/E+778'], [21, 'Schach-Mattinger Runde #21', 'GC9B5M6', 4858000, 1200750, 'a) Senkrecht N+75/E+250', 'b) Waagrecht N+5/E+180', 'c) Senkrecht und waagrecht N+67/E+220'], [34, 'Schach-Mattinger Runde #34', 'GC9B5QQ', 4857000, 1200300, 'a) Hongkong N-78/E-40.700', 'b) Saigon N-28/E-40.680', 'c) Bangkok N+65/E-40.677'], [20, 'Schach-Mattinger Runde #20', 'GC9B5KW', 4858000, 1200900, 'a) Weiße Bauern schlagen schwarze Läufer N+120/E+313', 'b) Weiß beginnt, Schwarz gewinnt N+99/E+289', 'c) Eine Dame kommt selten allein N-107/E+221'], [32, 'Schach-Mattinger Runde #32', 'GC9B5Q8', 4857200, 1200550, 'a) ein Feld vorwärts N+10/E-41.211', 'b) zwei Felder vorwärts N-28/E-41.429', 'c) ein Feld vorwärts diagonal N-28/E-41.230'], [15, 'Schach-Mattinger Runde #15', 'GC9B5JM', 4857800, 1201200, 'a) Dame N+665/E+901', 'b) König N+702/E+998', 'c) Turm N+697/E+832'], [8, 'Schach-Mattinger Runde #8', 'GC9B5HH', 4857000, 1201350, 'a) 1 N+55/E+135', 'b) 2 N+92/E+135', 'c) 3 N+110/E+135'], [16, 'Schach-Mattinger Runde #16', 'GC9B5JQ', 4857900, 1201200, 'a) Wenn man einen Bauern in eine beliebige Figur umtauschen darf N+479/E+747', 'b) Wenn man einen Läufer in eine beliebige Figur umtauschen darf N+559/E+689', 'c) Wenn man einen Turm in eine beliebige Figur umtauschen darf N+497/E+801'], [29, 'Schach-Mattinger Runde #29', 'GC9B5PK', 4857500, 1200550, 'a) Brettspiel N+40/E-41.136', 'b) Computerspiel N+55/E-41.277', 'c) Kartenspiel N+16/E-41.066'], [11, 'Schach-Mattinger Runde #11', 'GC9B5J2', 4857300, 1201100, 'a) Ja, immer N+125/E+676', 'b) Nein N+133/E+651', 'c) Ja, wenn beide Königinnen nicht mehr im Spiel sind N+112/E+622'], [10, 'Schach-Mattinger Runde #10', 'GC9B5HY', 4857200, 1201100, 'a) Wenn ein Spieler gle ...
